# %% [markdown]
# # DIPLOMATURA EN CIENCIA DE DATOS, APRENDIZAJE AUTOMÁTICO Y SUS APLICACIONES

# %% [markdown]
# ## Analisis y visuzlización de datos

# %%
import io
import matplotlib
import matplotlib.pyplot as plt
import numpy
import pandas as pd
import seaborn
import time
import datetime as dt
from IPython.display import HTML, display
import math

seaborn.set_context('talk')

# %%
url= 'https://raw.githubusercontent.com/laraccano84/Mentoria_mumuki/main/DiploDatos_Mentoria_Mumiki_G2/DataSet_Mumuki_Transformed.csv'
df_mumuki = pd.read_csv(url)

# %%
df_mumuki[:3]
# Out:
#    Unnamed: 0                              exercise_name expectation_results  \
# 0           0  Funciones, declaración / No tan distintos                  []
# 1           1  Funciones, declaración / No tan distintos                  []
# 2           2  Funciones, declaración / No tan distintos                  []
#
#                                           guide_slug result  sid  student_uid  \
# 0  mumukiproject/mumuki-guia-python-funciones-tip...    NaN    0           76
# 1  mumukiproject/mumuki-guia-python-funciones-tip...    NaN    1           77
# 2  mumukiproject/mumuki-guia-python-funciones-tip...    NaN    2           78
#
#                               submission_content    submission_created_at  \
# 0      def mitad(numero):\r\n  return numero / 2  2019-08-30 13:17:17.700
# 1      def mitad(numero):\r\n  return numero / 2  2019-09-04 01:29:22.351
# 2  def Mitas(numero):\r\n  return 2 / numero\r\n  2019-09-04 02:53:01.099
#
#   submission_status  ...  Month Week DayNroWeek DayNameWeek             Time  \
# 0            passed  ...      8   35          4      Friday  13:17:17.700000
# 1            passed  ...      9   36          2   Wednesday  01:29:22.351000
# 2            failed  ...      9   36          2   Wednesday  02:53:01.099000
#
#    Hora  Minute  lesson_number  exercise_index_per_lesson id_exercise
# 0    13      17              1                          1           1
# 1     1      29              1                          1           1
# 2     2      53              1                          1           1
#
# [3 rows x 26 columns]

# %% [markdown]
# # Frecuencia de acceso a la app

# %% [markdown]
# ## Cantidad envios por día

# %% [markdown]
# Grafico que muestra la candida de envios por dia, donde se visualiza con que frecuencia en el tiempo se realiza los envios.

# %%
df_mumuki=df_mumuki.sort_values('Date',ascending=True)

# %%
matplotlib.pyplot.figure(figsize = [20, 5] , dpi = None , facecolor = "wheat" , edgecolor = None , frameon = True  , clear = False )
ti = seaborn.histplot(data=df_mumuki, x=df_mumuki['Periodo'])

ti.set_xlabel('Fecha')
ti.set_ylabel('Cant Envios')
ti.set_title('Cantidad de envios en el tiempo', fontsize=20)
plt.show()

# %% [markdown]
# **A continuación se agrupa por periodo, donde tenemos la cantidad de envios, la cantidad de ejercicios, la cantidad de estudiante y la cantidad de dias.**

# %%
df_Periodo=df_mumuki.groupby(['Year','Month','Periodo'], as_index=False).agg({'id_exercise':'count','exercise_name': (lambda x: len(set(x))),'student_uid': (lambda x: len(set(x)))}).rename(columns={'id_exercise':'cant_envios','exercise_name':'cant_ejercicios_unicos','student_uid':'cant_student'})

# %%
df_Periodo
# Out:
#     Year  Month  Periodo  cant_envios  cant_ejercicios_unicos  cant_student
# 0   2019      8  2019-08            2                       2             1
# 1   2019      9  2019-09         4746                      40            54
# 2   2019     10  2019-10         2263                      40            45
# 3   2019     11  2019-11          580                      40            11
# 4   2019     12  2019-12           23                       7             1
# 5   2020      5  2020-05        15732                      40            98
# 6   2020      6  2020-06         3507                      40            62
# 7   2020      7  2020-07         1054                      40            34
# 8   2020      8  2020-08          494                      40             5
# 9   2020      9  2020-09        15305                      40            94
# 10  2020     10  2020-10         2791                      40            42
# 11  2020     11  2020-11          614                      40            18

# %%
fig, axes = plt.subplots(1, 1 , figsize=(15, 5))
seaborn.barplot(x="Periodo", y="cant_student", data=df_Periodo.sort_values('Periodo'))
# Out:
# <AxesSubplot:xlabel='Periodo', ylabel='cant_student'>

# %% [markdown]
# **A continuacion se agrupo por año-semana, donde tenemos la cantidad de envios, de ejercicios, de estudiantes y de dias por semana.**

# %%
df_week=df_mumuki.groupby(['Year','Week'], as_index=False).agg({'id_exercise':'count','exercise_name': (lambda x: len(set(x))),'student_uid': (lambda x: len(set(x)))}).rename(columns={'id_exercise':'cant_envios','exercise_name':'cant_ejercicios_unicos','student_uid':'cant_student'})

# %%
df_week
# Out:
#     Year  Week  cant_envios  cant_ejercicios_unicos  cant_student
# 0   2019    35            2                       2             1
# 1   2019    36          218                      27             3
# 2   2019    37           14                       5             1
# 3   2019    39         4166                      40            50
# 4   2019    40         1223                      40            25
# 5   2019    41          280                      33             7
# 6   2019    42          703                      40            18
# 7   2019    43          373                      40            11
# 8   2019    44           37                      14             7
# 9   2019    45          376                      40             7
# 10  2019    46           34                       9             2
# 11  2019    47          165                      37             3
# 12  2019    50           23                       7             1
# 13  2020    19         1077                      28            16
# 14  2020    20         4987                      40            50
# 15  2020    21         4034                      40            57
# 16  2020    22         5634                      40            67
# 17  2020    23          996                      40            34
# 18  2020    24         1058                      40            28
# 19  2020    25          949                      38            17
# 20  2020    26          437                      39            15
# 21  2020    27          169                      25            12
# 22  2020    28          178                      31             7
# 23  2020    29          688                      40            21
# 24  2020    30           86                      34             4
# 25  2020    31            5                       1             1
# 26  2020    32          119                      25             3
# 27  2020    33          180                      31             2
# 28  2020    34          164                      17             2
# 29  2020    35           26                       8             1
# 30  2020    36          136                      19             4
# 31  2020    37         6544                      40            57
# 32  2020    38         5215                      40            78
# 33  2020    39         2080                      40            45
# 34  2020    40         1484                      40            29
# 35  2020    41         1278                      40            26
# 36  2020    42          633                      40            12
# 37  2020    43          702                      40            13
# 38  2020    44           25                       8             4
# 39  2020    45          160                      30             5
# 40  2020    46          310                      40             7
# 41  2020    47           75                      29             5
# 42  2020    48           68                      40             2

# %%
fig, axes = plt.subplots(1, 1 , figsize=(15, 5))
seaborn.barplot(x="Week", y="cant_student", data=df_week.sort_values('Week'))
# Out:
# <AxesSubplot:xlabel='Week', ylabel='cant_student'>

# %% [markdown]
# **A continuacion se agrupa por estudiante, se contabiliza la cantidad de envios, de ejericios y de dias por estudiante.**

# %%
df_student = df_mumuki.groupby(['student_uid'], as_index=False).agg({'exercise_eid':'count','exercise_name': (lambda x: len(set(x))),'Date': (lambda x: len(set(x)))})

# %%
df_student.sort_values(by=['exercise_name'],ascending = True)
# Out:
#      student_uid  exercise_eid  exercise_name  Date
# 1             75             1              1     1
# 283          361             1              1     1
# 177          251             5              1     1
# 284          362             3              1     1
# 69           143             3              1     1
# ..           ...           ...            ...   ...
# 62           136           278             40     3
# 59           133           191             40     6
# 55           129           102             40     3
# 139          213           201             40     4
# 185          259           127             40     2
#
# [286 rows x 4 columns]

# %%
df_student.describe()
# Out:
#        student_uid  exercise_eid  exercise_name        Date
# count   286.000000    286.000000     286.000000  286.000000
# mean    216.304196    164.975524      31.150350    4.188811
# std      83.389648    108.342000      13.386893    2.515778
# min      -1.000000      1.000000       1.000000    1.000000
# 25%     145.250000     85.250000      22.250000    2.000000
# 50%     216.500000    148.500000      40.000000    4.000000
# 75%     287.750000    222.750000      40.000000    6.000000
# max     363.000000    660.000000      40.000000   15.000000

# %%
plt.figure(figsize=(10, 5))
seaborn.histplot(df_student['exercise_name'] , kde=True)
# Out:
# <AxesSubplot:xlabel='exercise_name', ylabel='Count'>

# %%
plt.figure(figsize=(12, 4))
seaborn.boxplot(x=df_student['Date'])
seaborn.despine()

# %%
plt.figure(figsize=(20, 8))
seaborn.histplot(df_student['Date'] , kde=True)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Count'>

# %%
customDistPlot = CustomDistPlot(plt)
customDistPlot.setScale(1)
columns_to_plot = df_student.select_dtypes(include=numpy.number).columns.tolist()
display_blox_plots(df = df_student , columns= columns_to_plot , displayGraph= customDistPlot)
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# **A continuación se determina el Tiempo entre un ejercico.**

# %%
df_order=df_mumuki[['student_uid','guide_slug', 'exercise_name', 'Estatus','submission_created_at']].sort_values(by=['student_uid','submission_created_at'],ascending = True)

# %%
df_order['prev_value'] = df_order['submission_created_at'].shift().where(df_order.student_uid.eq(df_order.student_uid.shift()))

# %%
df_order[:]
# Out:
#        student_uid                                         guide_slug  \
# 22309           -1  mumukiproject/mumuki-guia-python-funciones-tip...
# 22310           -1  mumukiproject/mumuki-guia-python-funciones-tip...
# 22311           -1  mumukiproject/mumuki-guia-python-funciones-tip...
# 22312           -1  mumukiproject/mumuki-guia-python-funciones-tip...
# 22313           -1  mumukiproject/mumuki-guia-python-funciones-tip...
# ...            ...                                                ...
# 33972          363  mumukiproject/mumuki-guia-python-practica-func...
# 33973          363  mumukiproject/mumuki-guia-python-practica-func...
# 33974          363  mumukiproject/mumuki-guia-python-practica-func...
# 33975          363  mumukiproject/mumuki-guia-python-practica-func...
# 33976          363  mumukiproject/mumuki-guia-python-practica-func...
#
#                                    exercise_name  Estatus  \
# 22309  Funciones, declaración / No tan distintos  no_paso
# 22310  Funciones, declaración / No tan distintos  no_paso
# 22311  Funciones, declaración / No tan distintos  no_paso
# 22312  Funciones, declaración / No tan distintos  no_paso
# 22313  Funciones, declaración / No tan distintos  no_paso
# ...                                          ...      ...
# 33972                         Cartelitos óptimos  no_paso
# 33973                         Cartelitos óptimos  no_paso
# 33974                         Cartelitos óptimos  no_paso
# 33975                         Cartelitos óptimos  no_paso
# 33976                         Cartelitos óptimos  no_paso
#
#          submission_created_at               prev_value
# 22309  2020-07-15 16:19:06.872                      NaN
# 22310  2020-07-15 16:19:41.159  2020-07-15 16:19:06.872
# 22311  2020-07-15 16:19:44.444  2020-07-15 16:19:41.159
# 22312  2020-07-15 16:19:47.470  2020-07-15 16:19:44.444
# 22313  2020-07-15 16:19:49.408  2020-07-15 16:19:47.470
# ...                        ...                      ...
# 33972  2020-10-06 14:45:08.643  2020-10-06 14:44:05.235
# 33973  2020-10-06 14:45:27.866  2020-10-06 14:45:08.643
# 33974  2020-10-06 14:45:35.999  2020-10-06 14:45:27.866
# 33975  2020-10-06 14:45:54.872  2020-10-06 14:45:35.999
# 33976  2020-10-06 14:46:04.134  2020-10-06 14:45:54.872
#
# [47183 rows x 6 columns]

# %%
df_order['differ'] = (pd.to_datetime(df_order['submission_created_at'])-pd.to_datetime(df_order['prev_value'])).dt.days

# %%
df_order.sort_values(by=['differ'],ascending = False)
# Out:
#        student_uid                                         guide_slug  \
# 5001            97  mumukiproject/mumuki-guia-python-funciones-tip...
# 22308          250  mumukiproject/mumuki-guia-python-funciones-tip...
# 45298          355  mumukiproject/mumuki-guia-python-variables-y-p...
# 22335          260  mumukiproject/mumuki-guia-python-funciones-tip...
# 2139           319  mumukiproject/mumuki-guia-python-funciones-tip...
# ...            ...                                                ...
# 16903          358  mumukiproject/mumuki-guia-python-funciones-tip...
# 22173          359  mumukiproject/mumuki-guia-python-funciones-tip...
# 25026          361  mumukiproject/mumuki-guia-python-practica-func...
# 26904          362  mumukiproject/mumuki-guia-python-practica-func...
# 30295          363  mumukiproject/mumuki-guia-python-practica-func...
#
#                                    exercise_name  Estatus  \
# 5001         Tipos de datos / Datos de todo tipo     paso
# 22308  Funciones, declaración / No tan distintos     paso
# 45298                               Conversiones  no_paso
# 22335  Funciones, declaración / No tan distintos     paso
# 2139                              Funciones, uso  no_paso
# ...                                          ...      ...
# 16903                           Operando strings  no_paso
# 22173  Funciones, declaración / No tan distintos     paso
# 25026                              ¿Me conviene?  no_paso
# 26904                                 Triangulos  no_paso
# 30295                                 Cartelitos  no_paso
#
#          submission_created_at               prev_value  differ
# 5001   2020-09-18 20:04:05.989  2019-10-23 11:49:33.276   331.0
# 22308  2020-10-12 17:17:17.822  2020-07-21 14:40:41.377    83.0
# 45298  2020-08-03 19:40:07.416  2020-05-26 14:44:42.028    69.0
# 22335  2020-11-23 20:15:28.657  2020-09-19 17:00:28.418    65.0
# 2139   2020-11-16 03:31:16.822  2020-09-23 00:31:53.947    54.0
# ...                        ...                      ...     ...
# 16903  2020-05-16 18:49:13.480                      NaN     NaN
# 22173  2020-05-14 22:42:31.975                      NaN     NaN
# 25026  2019-10-17 12:52:42.552                      NaN     NaN
# 26904  2019-10-17 14:35:27.705                      NaN     NaN
# 30295  2020-10-06 14:16:50.664                      NaN     NaN
#
# [47183 rows x 7 columns]

# %%
plt.figure(figsize=(12, 4))
seaborn.boxplot(x=df_order['differ'])
seaborn.despine()

# %%
#customHistPlot = CustomHistPlot(1000)

columns_to_plot = df_order.select_dtypes(include=numpy.number).columns.tolist()
display_blox_plots(df = df_order , columns= columns_to_plot , displayGraph= customHistPlot)

# %% [markdown]
# **A continuacion se detecta el Tiempo entre ejercicio y ejercicio por estudiante (se toma el ultimo envio por estudiante, ejercicio)**

# %%
df_byExercise = df_mumuki.groupby(['student_uid','exercise_name'], as_index=False).agg({'submission_created_at':'max','exercise_eid':'count'}).sort_values(by=['student_uid','submission_created_at'],ascending = True)

# %%
df_byExercise
# Out:
#       student_uid                              exercise_name  \
# 8              -1  Funciones, declaración / No tan distintos
# 9              -1                             Funciones, uso
# 16             -1                         Probando funciones
# 10             -1                           Haciendo cuentas
# 11             -1                 Libros de la buena memoria
# ...           ...                                        ...
# 8904          361                              ¿Me conviene?
# 8905          362                                 Triangulos
# 8906          363                                 Cartelitos
# 8908          363                             Más Cartelitos
# 8907          363                         Cartelitos óptimos
#
#         submission_created_at  exercise_eid
# 8     2020-07-15 16:22:00.640            11
# 9     2020-07-15 16:25:48.109             2
# 16    2020-07-15 16:36:14.413             3
# 10    2020-07-15 16:38:41.638             7
# 11    2020-07-15 16:49:36.204             3
# ...                       ...           ...
# 8904  2019-10-17 12:52:42.552             1
# 8905  2019-10-17 14:36:54.224             3
# 8906  2020-10-06 14:17:51.060             3
# 8908  2020-10-06 14:27:26.752             4
# 8907  2020-10-06 14:46:04.134            12
#
# [8909 rows x 4 columns]

# %%
df_byExercise['prev_value_E'] = df_byExercise['submission_created_at'].shift().where(df_byExercise.student_uid.eq(df_byExercise.student_uid.shift()))

# %%
df_byExercise
# Out:
#       student_uid                              exercise_name  \
# 8              -1  Funciones, declaración / No tan distintos
# 9              -1                             Funciones, uso
# 16             -1                         Probando funciones
# 10             -1                           Haciendo cuentas
# 11             -1                 Libros de la buena memoria
# ...           ...                                        ...
# 8904          361                              ¿Me conviene?
# 8905          362                                 Triangulos
# 8906          363                                 Cartelitos
# 8908          363                             Más Cartelitos
# 8907          363                         Cartelitos óptimos
#
#         submission_created_at  exercise_eid             prev_value_E
# 8     2020-07-15 16:22:00.640            11                      NaN
# 9     2020-07-15 16:25:48.109             2  2020-07-15 16:22:00.640
# 16    2020-07-15 16:36:14.413             3  2020-07-15 16:25:48.109
# 10    2020-07-15 16:38:41.638             7  2020-07-15 16:36:14.413
# 11    2020-07-15 16:49:36.204             3  2020-07-15 16:38:41.638
# ...                       ...           ...                      ...
# 8904  2019-10-17 12:52:42.552             1                      NaN
# 8905  2019-10-17 14:36:54.224             3                      NaN
# 8906  2020-10-06 14:17:51.060             3                      NaN
# 8908  2020-10-06 14:27:26.752             4  2020-10-06 14:17:51.060
# 8907  2020-10-06 14:46:04.134            12  2020-10-06 14:27:26.752
#
# [8909 rows x 5 columns]

# %%
df_byExercise['differ_E'] = (pd.to_datetime(df_byExercise['submission_created_at'])-pd.to_datetime(df_byExercise['prev_value_E'])).dt.days

# %%
df_byExercise.sort_values(by=['differ_E'],ascending = False)
# Out:
#       student_uid                              exercise_name  \
# 416            97        Tipos de datos / Datos de todo tipo
# 5173          250  Funciones, declaración / No tan distintos
# 8883          355                               Conversiones
# 5532          260  Funciones, declaración / No tan distintos
# 7799          319                             Funciones, uso
# ...           ...                                        ...
# 8887          358                           Operando strings
# 8893          359  Funciones, declaración / No tan distintos
# 8904          361                              ¿Me conviene?
# 8905          362                                 Triangulos
# 8906          363                                 Cartelitos
#
#         submission_created_at  exercise_eid             prev_value_E  differ_E
# 416   2020-09-18 20:05:03.146            11  2019-10-23 11:49:33.276     331.0
# 5173  2020-10-12 17:17:17.822             6  2020-07-21 14:40:41.377      83.0
# 8883  2020-08-03 19:40:07.416             1  2020-05-26 14:44:42.028      69.0
# 5532  2020-11-23 20:15:28.657             4  2020-09-19 17:00:28.418      65.0
# 7799  2020-11-21 15:17:26.661            35  2020-09-23 00:31:53.947      59.0
# ...                       ...           ...                      ...       ...
# 8887  2020-05-16 18:50:49.407             6                      NaN       NaN
# 8893  2020-05-14 22:42:31.975             1                      NaN       NaN
# 8904  2019-10-17 12:52:42.552             1                      NaN       NaN
# 8905  2019-10-17 14:36:54.224             3                      NaN       NaN
# 8906  2020-10-06 14:17:51.060             3                      NaN       NaN
#
# [8909 rows x 6 columns]

# %%
plt.figure(figsize=(12, 4))
seaborn.boxplot(x=df_byExercise['differ_E'])
seaborn.despine()

# %%
#customHistPlot = CustomHistPlot(1000)

columns_to_plot = df_byExercise.select_dtypes(include=numpy.number).columns.tolist()
display_blox_plots(df = df_byExercise , columns= columns_to_plot , displayGraph= customHistPlot)
